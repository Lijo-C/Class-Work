# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df_2025 = df[df['year'] == 2025]

# %%
plt.figure(figsize=(6,4))
plt.bar(df_2025['retailer'], df_2025['online_revenue_million'], color=['#377eb8','#ff7f00','#4daf4a'])
plt.ylabel('Online Revenue (Million €)')
plt.title('Online Revenue by Retailer in 2025')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(df_2025['online_revenue_million'], labels=df_2025['retailer'], autopct='%1.1f%%', colors=['#377eb8','#ff7f00','#4daf4a'])
plt.title('Revenue Share in 2025')
plt.show()

# %%
plt.figure(figsize=(8,4))
for retailer in df['retailer'].unique():
    df_r = df[df['retailer'] == retailer]
    plt.plot(df_r['year'], df_r['conversion_rate_percent'], marker='o', label=retailer)

# %%
plt.figure(figsize=(8,4))
for retailer in df['retailer'].unique():
    df_r = df[df['retailer'] == retailer]
    plt.plot(df_r['year'], df_r['conversion_rate_percent'], marker='o', label=retailer)

plt.xlabel('Year')
plt.ylabel('Conversion Rate (%)')
plt.title('Conversion Rate Trend (2021-2025)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
df_2025 = df[df['year'] == 2025]

plt.figure(figsize=(7,5))
plt.bar(df_2025['retailer'], df_2025['online_revenue_million'], color=['#377eb8', '#ff7f00', '#4daf4a'])
plt.ylabel('Online Revenue (€ Million)')
plt.title('Online Revenue by Retailer (July 2025)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df_2025['online_revenue_million'], labels=df_2025['retailer'], autopct='%1.1f%%', colors=['#377eb8', '#ff7f00', '#4daf4a'])
plt.title('Market Share by Online Revenue (July 2025)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
for retailer in df['retailer'].unique():
    df_rt = df[df['retailer'] == retailer]
    plt.plot(df_rt['year'], df_rt['conversion_rate_percent'], marker='o', label=retailer)

plt.xlabel('Year')
plt.ylabel('Conversion Rate (%)')
plt.title('Conversion Rate Trend (2021 - 2025)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(df_2025['retailer'], df_2025['website_sessions_million'], color=['#377eb8', '#ff7f00', '#4daf4a'])
plt.ylabel('Website Sessions (Million)')
plt.title('Website Sessions by Retailer (July 2025)')
plt.tight_layout()
plt.show()

# %%
df_2025 = df_2025.copy()
df_2025['revenue_per_session'] = df_2025['online_revenue_million'] / df_2025['website_sessions_million']

plt.figure(figsize=(7,5))
plt.bar(df_2025['retailer'], df_2025['revenue_per_session'], color=['#377eb8', '#ff7f00', '#4daf4a'])
plt.ylabel('Revenue per Session (€)')
plt.title('Revenue per Session by Retailer (July 2025)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# ...

# %%
df_2025 = df[df['year'] == 2025]

# %%
df_2025 = df_2025.copy()
df_2025['revenue_per_session'] = df_2025['online_revenue_million'] / df_2025['website_sessions_million']

plt.figure(figsize=(7,5))
plt.bar(df_2025['retailer'], df_2025['revenue_per_session'], color=['#377eb8', '#ff7f00', '#4daf4a'])
plt.ylabel('Revenue per Session (€)')
plt.title('Revenue per Session by Retailer (July 2025)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# ...

# %%
df = pd.read_csv('dm_ecommerce_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-1004321470.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('dm_ecommerce_data.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df = pd.read_csv('/content/dm_ecommerce_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-777249992.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/dm_ecommerce_data.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...
