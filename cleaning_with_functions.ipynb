# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_org = pd.read_csv('/content/bank_data-1.csv')
print(df_org.shape)
df_org.head()
# Out:
# (10000, 13)
#          id last_name  credit_score      country gender  age  years_customer  \
# 0  15634602  Hargrave           619  Switzerland      f   42               2
# 1  15647311      Hill           608      Austria      f   41               1
# 2  15619304      Onio           502  Switzerland      f   42               8
# 3  15701354      Boni           699  Switzerland      f   39               1
# 4  15737888  Mitchell           850      Austria      f   43               2
#
#    balance_euros  num_products  has_credit_card  is_active  salary_euros  \
# 0           0.00             1                1          1     101348.88
# 1       83807.86             1                0          1     112542.58
# 2      159660.80             3                1          0     113931.57
# 3           0.00             2                0          0      93826.63
# 4      125510.82             1                1          1      79084.10
#
#    retained
# 0         0
# 1         1
# ...

# %%
def convert(inp):
  if inp == "f":
    return 1
  else:
    return 0

convert("f")
# Out:
# 1

# %%
def convert(inp):
  if inp == "f":
    return 1
  else:
    return 0

convert("m")
# Out:
# 0

# %% [markdown]
# assinging 1 and 0 in the gender column

# %%
def convert(x):
  if x == "f":
    return 1
  else:
    return 0

df = df_org.copy()

df['gender'] = df['gender'].apply(convert)
df.head(10)
# Out:
#          id last_name  credit_score      country  gender  age  years_customer  \
# 0  15634602  Hargrave           619  Switzerland       1   42               2
# 1  15647311      Hill           608      Austria       1   41               1
# 2  15619304      Onio           502  Switzerland       1   42               8
# 3  15701354      Boni           699  Switzerland       1   39               1
# 4  15737888  Mitchell           850      Austria       1   43               2
# 5  15574012       Chu           645      Austria       0   44               8
# 6  15592531  Bartlett           822  Switzerland       0   50               7
# 7  15656148    Obinna           376      Germany       1   29               4
# 8  15792365        He           501  Switzerland       0   44               4
# 9  15592389        Hu           684  Switzerland       0   27               2
#
#    balance_euros  num_products  has_credit_card  is_active  salary_euros  \
# ...

# %% [markdown]
# Create a new column and value of in in correspomding to the reatined column

# %%
def convert(x):
  if x == "f":
    return 1
  else:
    return 0

def convert2(x):
  if x == "f":
    return 1
  else:
    return 0

df = df_org.copy()

df['gender'] = df['gender'].apply(convert)
df['churn'] = df['retained'].apply(convert2)
df.head(10)
# Out:
#          id last_name  credit_score      country  gender  age  years_customer  \
# 0  15634602  Hargrave           619  Switzerland       1   42               2
# 1  15647311      Hill           608      Austria       1   41               1
# 2  15619304      Onio           502  Switzerland       1   42               8
# 3  15701354      Boni           699  Switzerland       1   39               1
# 4  15737888  Mitchell           850      Austria       1   43               2
# 5  15574012       Chu           645      Austria       0   44               8
# 6  15592531  Bartlett           822  Switzerland       0   50               7
# 7  15656148    Obinna           376      Germany       1   29               4
# 8  15792365        He           501  Switzerland       0   44               4
# 9  15592389        Hu           684  Switzerland       0   27               2
#
#    balance_euros  num_products  has_credit_card  is_active  salary_euros  \
# ...

# %%
def convert(x):
  if x == "f":
    return 1
  else:
    return 0

df = df_org.copy()

df['gender'] = df['gender'].apply(lambda x:1 if x=='f' else 0)
# df['churn'] = df['retained'].apply()
df.head(10)
# Out:
#          id last_name  credit_score      country  gender  age  years_customer  \
# 0  15634602  Hargrave           619  Switzerland       1   42               2
# 1  15647311      Hill           608      Austria       1   41               1
# 2  15619304      Onio           502  Switzerland       1   42               8
# 3  15701354      Boni           699  Switzerland       1   39               1
# 4  15737888  Mitchell           850      Austria       1   43               2
# 5  15574012       Chu           645      Austria       0   44               8
# 6  15592531  Bartlett           822  Switzerland       0   50               7
# 7  15656148    Obinna           376      Germany       1   29               4
# 8  15792365        He           501  Switzerland       0   44               4
# 9  15592389        Hu           684  Switzerland       0   27               2
#
#    balance_euros  num_products  has_credit_card  is_active  salary_euros  \
# ...

# %% [markdown]
# another method to add column and change the value of gender as well as the churn column

# %%
def convert(x):
  if x == "f":
    return 1
  else:
    return 0

df = df_org.copy()

df['gender'] = df['gender'].apply(lambda x:1 if x=='f' else 0)
df['churn'] = df['retained'].apply(lambda x:1 if x==0 else 0)
df.head(10)
# Out:
#          id last_name  credit_score      country  gender  age  years_customer  \
# 0  15634602  Hargrave           619  Switzerland       1   42               2
# 1  15647311      Hill           608      Austria       1   41               1
# 2  15619304      Onio           502  Switzerland       1   42               8
# 3  15701354      Boni           699  Switzerland       1   39               1
# 4  15737888  Mitchell           850      Austria       1   43               2
# 5  15574012       Chu           645      Austria       0   44               8
# 6  15592531  Bartlett           822  Switzerland       0   50               7
# 7  15656148    Obinna           376      Germany       1   29               4
# 8  15792365        He           501  Switzerland       0   44               4
# 9  15592389        Hu           684  Switzerland       0   27               2
#
#    balance_euros  num_products  has_credit_card  is_active  salary_euros  \
# ...

# %% [markdown]
# Data basic cleaning and feature engineering

# %%
df = df_org.copy()

print('count of nan:'. )

df['gender'] = df['gender'].apply(lambda x:1 if x=='f' else 0)
df['churn'] = df['retained'].apply(lambda x:1 if x==0 else 0)
df.head(10)
# Out:
#   File "/tmp/ipython-input-1381451670.py", line 3
#     print('count of nan:'. )
#                            ^
# SyntaxError: invalid syntax

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
display(df['churn'].value_counts())
sns.countplot(data=df,x='churn')
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64
# <Axes: xlabel='churn', ylabel='count'>

# %%
display(df['country'].value_counts())
sns.countplot(data=df,x='country')
# Out:
# country
# Switzerland    5014
# Germany        2509
# Austria        2477
# Name: count, dtype: int64
# <Axes: xlabel='country', ylabel='count'>

# %%
display(df['gender'].value_counts())
sns.countplot(data=df,x='gender')
# Out:
# gender
# 0    5457
# 1    4543
# Name: count, dtype: int64
# <Axes: xlabel='gender', ylabel='count'>

# %%
country_cnt=df["country"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(country_cnt, labels=country_cnt.index, autopct='%1.2f%%',stratangle=120, wedgeprops={'edgecolor':'white'})
plt.title('Customer Distribution by Country')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1698895882.py in <cell line: 0>()
# ----> 1 country_cnt=df["country"].value_counts()
#       2
#       3 plt.figure(figsize=(6,6))
#       4 plt.pie(country_cnt, labels=country_cnt.index, autopct='%1.2f%%',stratangle=120, wedgeprops={'edgecolor':'white'})
#       5 plt.title('Customer Distribution by Country')
#
# NameError: name 'df' is not defined

# %%
df['churn'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-253567296.py in <cell line: 0>()
# ----> 1 df['churn'].value_counts()
#
# NameError: name 'df' is not defined
